# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhojit-malik/data-engineering-journey/blob/main/Python/Python_Day_01_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("My name is Subhojit")
print("I am learning Python")
print("Today is Day 1")
# Out:
# My name is Subhojit
# I am learning Python
# Today is Day 1

# %%
print("My name is Subhojit")
print("I am learning python")
print("I want to become a Data Engineer")
# Out:
# My name is Subhojit
# I am learning python
# I want to become a Data Engineer

# %%
print(10)
# Out:
# 10

# %%
print(20)
print(10 + 20)
# Out:
# 20
# 30

# %%
name = "Subhojit"
age = 27
salary = 40000

# %%
print(name)
# Out:
# Subhojit

# %%
print(age)
# Out:
# 27

# %%
print(salary)
# Out:
# 40000

# %%
name = "Subhojit"
age = 28

# %%
print("My name is", name)
print("My age is", age)
# Out:
# My name is Subhojit
# My age is 28

# %%
name = "Subhojit"

# %%
city = "Kolkata"
experience = "4 Years 10 Months"
target_role = "Data Engineer"

# %%
print("My name is", name)
print("My hometown is", city)
print("I have total", experience,"experience")
print("I want to join as a", target_role)
# Out:
# My name is Subhojit
# My hometown is Kolkata
# I have total 4 Years 10 Months experience
# I want to join as a Data Engineer

# %%
a = 10
b = 20

print(a + b)
# Out:
# 30

# %%
a = 20
b = 5

# %%
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0

# %%
salary = 40000
bonus = 4000

print("Salary + bonus:", salary + bonus)
print("Salary - bonus:", salary - bonus)
print("Double salary:", salary * 2)
print("Half salary:", salary / 2)
# Out:
# Salary + bonus: 44000
# Salary - bonus: 36000
# Double salary: 80000
# Half salary: 20000.0

# %%
name = "Subhojit"

# %%
age = 27
salary = 40000
experience = 4.10
is_learning = True

# %%
print(type(name))
print(type(age))
print(type(salary))
print(type(experience))
print(type(is_learning))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
name = "Subhojit"
age = 27
salary = 40000
city = "Kolkata"
is_working = True

# %%
print(type(name))
print(type(age))
print(type(salary))
print(type(city))
print(type(is_working))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
