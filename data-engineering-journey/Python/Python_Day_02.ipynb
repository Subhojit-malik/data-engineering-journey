# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhojit-malik/data-engineering-journey/blob/main/data-engineering-journey/Python/Python_Day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 2
c = a//b
print(c) #Floor division case-1
# Out:
# 5

# %%
a1 = 11
b1 = 2
c1 = a1//b1
print(c1) #Floor division case-1
# Out:
# 5

# %%
a2 = -10
b2 = 2
c2 = a2//b2
print(c2) #Floor division case-2
# Out:
# -5

# %%
a3 = 10
b3 = -2
c3 = a3//b3
print(c3) #Floor division case-2
# Out:
# -5

# %%
a4 = 11
b4 = -3
c4 = a4//b4
print(c4) #Floor division case-3
# Out:
# -4

# %%
a5 = 43
b5 = 2
c5 = a5%b5
print(c5) #This is Modulus
# Out:
# 1

# %%
a6 = 3
b6 = 2
c6 = a6**b6
print(c6) #This is Exponentiation
# Out:
# 9

# %%
a7 = 10
c7 = 2
#c7 = a7+c7
c7 += a7

# %%
print(c7)
# Out:
# 22

# %%
print(c7)
# Out:
# 22

# %%
a = 10
'''here,
a is Variable
10 is Value
'=' is Assignment opertor '''
# Out:
# "here,\na is Variable\n10 is Value\n'=' is Assignment opertor "

# %%
x = 34
y = x
print('x = ',x, ';  id of x= ', id(x))
print('y = ',y, ';  id of y= ', id(y))
# Out:
# x =  34 ;  id of x=  11278984
# y =  34 ;  id of y=  11278984

# %%
x = 65
print('x = ',x, ';  id of x= ', id(x))
print('y = ',y, ';  id of y= ', id(y))
# Out:
# x =  65 ;  id of x=  11279976
# y =  34 ;  id of y=  11278984

# %%
y = 78
print('x = ',x, ';  id of x= ', id(x))
print('y = ',y, ';  id of y= ', id(y))
# Out:
# x =  65 ;  id of x=  11279976
# y =  78 ;  id of y=  11280392

# %%
# Arithmetic Operators
# + = Addition
x = 12; y = 50
print(x + y)
# Out:
# 62

# %%
# - = Subtraction
x = 45; y = 24
print(x-y)
# Out:
# 21

# %%
# * = multiplication
x = 50; y = 4
print(x * y)
# Out:
# 200

# %%
# / = division
x = 20; y = 5
print(x/y)
# Out:
# 4.0

# %%
# % = modulo
x = 50; y = 4
print(x%y)
# Out:
# 2

# %%
# // = integer divide/ floor division
x = 50; y = 4
print(x//y)
# Out:
# 12

# %%
# ** = Exponent
x = 3; y = 3
print(x**y)
# Out:
# 27

# %%
# Assignment operator
a=5
a += 5
print(a)
# Out:
# 10

# %%
#Comparision operator
# == : Returns true if two values are equal
x = 20; y = 20
print(x==y)
# Out:
# True

# %%
# != : Returns true if two values are not equal
x = 45; y = 25
print(x!=y)
# Out:
# True

# %%
# < operator
x = 50; y = 70
print(x<y)
# Out:
# True

# %%
# > operator
x = 20; y =30
print(x>y)
# Out:
# False

# %%
# >= and <=
a = 5; b = 9
x = 10; y = 10
print(a>=b)
print(x<=y)
# Out:
# False
# True
